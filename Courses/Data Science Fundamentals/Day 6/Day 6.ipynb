# %% [markdown]
# <H1 > Welcome to Data Science Fundamentals: Pandas to Predictions</H1>
#
# <p align="center">
#   <img src="Datafain logo.jpg"/>
# </p>
#
# Hello. My name is [Ridwan Salahuddeen](https://www.linkedin.com/in/ridwan-salahuddeen/) and I shall be taking you through on this class.
#
# Follow [DataFain](https://www.linkedin.com/company/data-for-all-initiative) on LinkedIn

# %% [markdown]
# ## Table of Contents
# <font >
# <ol>
# <li> Ice Breaker: What is Data Science?, Data Science Tools, Numpy Introduction, Quiz 1
# <li> Importance of Numpy,More Hands-on Use of Numpy,Quiz 2,Assignment 1
# <li> Introduction to Pandas: Creating Dataframes and Reading From Files,Quiz 3
# <li> More on Pandas: Manipulating Dataframes,Quiz 4,Assignment 2
# <li> Introduction to Matplotlib: Plotting Simple Charts,Quiz 5
#
# <li> More on Matplotlib: Drawing Inference from plots,Quiz 6,Assignment 3
# <li> Types of Machine Learning Algorithms,Quiz 7
# <li> Understanding Learning Algorithms - Logistic Regression,Quiz 8,Assignment 4
# <li> Using Sci-Kit Learn: Logistic Regression,Sample Classification Problem1,Quiz 9
# <li> Sample Classification Problem 2,Quiz 10,Assignment 5
# </ol>
# </font>

# %% [markdown]
# ### Recap of Last Class

# %% [markdown]
# In the previous class, we learnt:
# >1. about the anatomy of a plot
# >2. how to create a figure container for plots
# >3. about the types of Plots
# >4. how to create simple plots using the pyplot API
# >5. about the PyLab module

# %% [markdown]
# # Today: Drawing Inference from plots
#
# > 1. Using the Object oriented interface
# > 2. Creating multiple plots
# > 3. More on plot formatting
# > 4. Plotting data from a dataframe
# > 5. Interpreting plots

# %% [markdown]
# ### Using the Object oriented interface

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# You can create multiple plots like this

def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

# plt.figure()
plt.subplot(211)
plt.plot(t1, f(t1), 'b*', t2, f(t2), 'k')


plt.subplot(212)
plt.plot(t2, np.cos(np.pi*t2), 'r--')
plt.show()

# %% [markdown]
# `plt.subplots(nrows=1,ncols=1,sharex=False,sharey=False,squeeze=True,subplot_kw=None,gridspec_kw=None,**fig_kw)`

# %%
fig, ax = plt.subplots(1,1)
ax.plot([1,3,4,7], [3,6,10,33])

# %% [markdown]
# ### Creating multiple plots

# %%
x = np.arange(10)

# Creating a figure and specifying it's axes
fig, axs = plt.subplots(2,2, figsize=(16,16))

# Unpack the axes array created
(ax1, ax2), (ax3, ax4)= axs

ax1.plot(x, np.random.randn(10)*x)
ax2.scatter(x*np.random.randn(10), x**2)
ax3.bar(x, x**3/2)
ax4.pie(x, labels = np.arange(10), autopct ='%1.2f%%')
plt.show()

# %% [markdown]
# ### More on plot formatting

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot([1,2, 3, 5], [3,6, 20, 50], "bo", [2,5, 10, 25], [5,25, 125, 60], "r*")
ax.text(12, 50, "Text illustration", fontsize = 12, color="g")
ax.set_title("Hello World")
ax.set_label("Blue")
plt.grid(lw = 1.25)

plt.show()
# Out:
# Spine

# %% [markdown]
# ### Plotting data from a dataframe

# %%
import pandas as pd
df = pd.read_html('https://github.com/pandas-dev/pandas/blob/master/doc/data/air_quality_no2.csv')[0].drop('Unnamed: 0', axis = 1)
df
# Out:
#                  datetime  station_antwerp  station_paris  station_london
# 0     2019-05-07 02:00:00              NaN            NaN            23.0
# 1     2019-05-07 03:00:00             50.5           25.0            19.0
# 2     2019-05-07 04:00:00             45.0           27.7            19.0
# 3     2019-05-07 05:00:00              NaN           50.4            16.0
# 4     2019-05-07 06:00:00              NaN           61.9             NaN
# ...                   ...              ...            ...             ...
# 1030  2019-06-20 22:00:00              NaN           21.4             NaN
# 1031  2019-06-20 23:00:00              NaN           24.9             NaN
# 1032  2019-06-21 00:00:00              NaN           26.5             NaN
# 1033  2019-06-21 01:00:00              NaN           21.8             NaN
# 1034  2019-06-21 02:00:00              NaN           20.0             NaN
#
# [1035 rows x 4 columns]

# %%
# In order to plot data from a dataframe, you first need to extract the data as an array or series
datetime = df.datetime
paris = df.station_paris
london = df.station_london
antwerp = df.station_antwerp

# %%
fig, axs = plt.subplots(3,2, figsize = (10, 10))
# To be completed during the class

# %% [markdown]
# ### Interpreting plots

# %%
df.groupby('datetime').sum()
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              0.0            0.0            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              0.0           50.4            16.0
# 2019-05-07 06:00:00              0.0           61.9             0.0
# ...                              ...            ...             ...
# 2019-06-20 22:00:00              0.0           21.4             0.0
# 2019-06-20 23:00:00              0.0           24.9             0.0
# 2019-06-21 00:00:00              0.0           26.5             0.0
# 2019-06-21 01:00:00              0.0           21.8             0.0
# 2019-06-21 02:00:00              0.0           20.0             0.0
#
# [1035 rows x 3 columns]

# %%
# pd.to_datetime(df.datetime.to_timestamp.values, freq=)
time = df.datetime.astype(np.datetime64)#.to_timestamp(freq = 'D')
time.dt.week.unique()
# Out:
# array([19, 20, 21, 22, 23, 24, 25], dtype=int64)

# %%
fig = plt.figure(figsize = (10,8))
plt.plot(time
            , df.station_london.values)
plt.show()

# %%
df.set_index('datetime').plot(y = 'station_london', figsize = (10,8), )

# %% [markdown]
# # Practice Problems

# %%
# Question 1: Create a plot of a circle with the data below and add title and axes labels
x = np.linspace(-3, 3, 500)
y = np.sqrt((np.max(x**2)-x**2))

# Create a figure with size 8, 8
plt.____(figsize=____)

# Call plot method twice, reversing 
plt._____(x, y, "b-")
plt._____(x, -y, "b-")

# Add Labels and title
plt.____(____)
plt.____(____)
plt.____(____)
plt.show()

# %%
# Question 2: 
# 1. Create a histogram with the following variable. Use 30 bins (hint: check the arguments that the plot type takes)
# 2. Add title and labels 
# 3. Answer the question: What kind of distribution in produced?

x = np.random.randn(10000)

plt.____(x, bins = 30, label=____)

# Add Labels and title
plt.____(____)
plt.____(____)
plt.____(____)

plt.legend()
plt.show()

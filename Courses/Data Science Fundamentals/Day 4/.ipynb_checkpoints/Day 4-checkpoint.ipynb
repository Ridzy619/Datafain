# %% [markdown]
# <H1 > Welcome to Data Science Fundamentals: Pandas to Predictions</H1>
#
# <p align="center">
#   <img src="Datafain logo.jpg"/>
# </p>
#
# Hello. My name is [Ridwan Salahuddeen](https://www.linkedin.com/in/ridwan-salahuddeen/) and I shall be taking you through on this class.
#
# Follow [DataFain](https://www.linkedin.com/company/data-for-all-initiative) on LinkedIn

# %% [markdown]
# ## Table of Contents
# <font >
# <ol>
# <li> Ice Breaker: What is Data Science?, Data Science Tools, Numpy Introduction, Quiz 1
# <li> Importance of Numpy,More Hands-on Use of Numpy,Quiz 2,Assignment 1
# <li> Introduction to Pandas: Creating Dataframes and Reading From Files,Quiz 3
# <li> More on Pandas: Manipulating Dataframes,Quiz 4,Assignment 2
# <li> Introduction to Matplotlib: Plotting Simple Charts,Quiz 5
#
# <li> More on Matplotlib: Drawing Inference from plots,Quiz 6,Assignment 3
# <li> Types of Machine Learning Algorithms,Quiz 7
# <li> Understanding Learning Algorithms - Logistic Regression,Quiz 8,Assignment 4
# <li> Using Sci-Kit Learn: Logistic Regression,Sample Classification Problem1,Quiz 9
# <li> Sample Classification Problem 2,Quiz 10,Assignment 5
# </ol>
# </font>

# %% [markdown]
# ### Recap of Last Class

# %% [markdown]
# > Reading files from excel, csv, json and html using `pd.read_{}` where the curly braces is replaced by the respective file types.
#
# Download the [California Housing Prices](https://github.com/ageron/handson-ml/raw/master/datasets/housing/housing.csv) dataset for this practice

# %%
import pandas as pd

# Example: Read a csv file
file = r"C:\Users\HP\Documents\Ridwan\DataFAIN\Datafain\Courses\Data Science Fundamentals\Day 4\california_housing_train.csv"
df = pd.read_csv(file)
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %% [markdown]
# > Slicing columns and rows; using mask to slice rows

# %%
# displaying total rooms and households columns
df[['total_rooms', 'households']]
# Out:
#        total_rooms  households
# 0           5612.0       472.0
# 1           7650.0       463.0
# 2            720.0       117.0
# 3           1501.0       226.0
# 4           1454.0       262.0
# ...            ...         ...
# 16995       2217.0       369.0
# 16996       2349.0       465.0
# 16997       2677.0       456.0
# 16998       2672.0       478.0
# 16999       1820.0       270.0
#
# [17000 rows x 2 columns]

# %%
# displaying total rooms and households columns for only records with housing median age that is greater than 15 years
df[['total_rooms', 'households']][df['housing_median_age'] > 15]
# Out:
#        total_rooms  households
# 1           7650.0       463.0
# 2            720.0       117.0
# 4           1454.0       262.0
# 5           1387.0       239.0
# 6           2907.0       633.0
# ...            ...         ...
# 16995       2217.0       369.0
# 16996       2349.0       465.0
# 16997       2677.0       456.0
# 16998       2672.0       478.0
# 16999       1820.0       270.0
#
# [14275 rows x 2 columns]

# %% [markdown]
# > Creating a scatter plot of total rooms vs households

# %%
# a = df[['total_rooms', 'households']]
ax = df.plot.scatter(x = 'total_rooms', y = 'households')

# %% [markdown]
# # Today: More on Pandas: Manipulating Dataframes
#
# > 1. Creating new columns derived from existing columns; rename columns
# > 2. Indexing and reindexing.
# > 2. Calculating summary statistics
# > 4. Reshaping a DataFrame
# > 5. Combining DataFrames
# > 6. Handling missing data

# %% [markdown]
# ## Creating new columns derived from existing columns; renaming columns
#
# Using the California housing dataset referenced earlier with a link:

# %%
import pandas as pd

# Example: Read a csv file
file = r"C:\Users\HP\Documents\Ridwan\DataFAIN\Datafain\Courses\Data Science Fundamentals\Day 4\california_housing_train.csv"
df = pd.read_csv(file)
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# **Let us create a new column which is the number of people per household**

# %%
df['population_per_household'] = df['population'] / df['households']
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value  \
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0
#
#    population_per_household
# 0                  2.150424
# 1                  2.438445
# 2                  2.846154
# 3                  2.278761
# ...

# %% [markdown]
# **Let us rename `median_house_value` and `population_per_household` to `med_house_val` and `pop_per_house` respectively**
#
# **Let us also rename indices `0` and `1` to `00` and `11` respectively**

# %%
col_new_names = {'median_house_value':'med_house_val',
                 'population_per_household': 'pop_per_house'}
index_new_names = {0:'00',
                1:'11'}

df.rename(columns=col_new_names, index= index_new_names)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 00       -114.31     34.19                15.0       5612.0          1283.0
# 11       -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %% [markdown]
# ## Indexing loc `loc` & `iloc` and reindexing with `reindex`
#
# Indexing and reindexing are used to get a subset of a DataFrame by using the row index sequence, row index name, column index sequence or column index name as will be illustrated below.

# %%
# Example 1: loc only supports indexing by name
df.loc[[0,1,2,5,7,10], ['latitude', 'longitude']]
# Out:
#     latitude  longitude
# 0      34.19    -114.31
# 1      34.40    -114.47
# 2      33.69    -114.56
# 5      33.63    -114.58
# 7      34.83    -114.59
# 10     33.62    -114.60

# %%
# Example 2: iloc supports indexing by index sequence
df.iloc[[4,5,6], [7,3,6,9]]
# Out:
#    median_income  total_rooms  households  population_per_household
# 4         1.9250       1454.0       262.0                  2.381679
# 5         3.3438       1387.0       239.0                  2.807531
# 6         2.6768       2907.0       633.0                  2.908373

# %% [markdown]
# ## Calculating summary statistics
#
# Summary statistics can be calculated accross rows and columns

# %%
# Example 1: Calculating mean of population of the DataFrame
df['population'].mean()
# Out:
# 1429.5739411764705

# %%
# Example 2: calculating the standard deviation of the population
df['population'].std()
# Out:
# 1147.8529591595266

# %%
# Example 3: use describe function to print multiple summary statistics. It can be used with a Series object or a DataFrame object
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# ## Sorting a DataFrame
# > 1. Sorting a Dataframe by a column/or columns
# > 2. Pivoting a Dataframe

# %% [markdown]
# **Sorting a Dataframe by a column/or columns**

# %%
# Example 1: Sorting by a single column
df.sort_values('population')
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8232     -118.44     34.04                16.0         18.0             6.0
# 2990     -117.79     35.21                 4.0          2.0             2.0
# 2907     -117.76     35.22                 4.0         18.0             3.0
# 14105    -122.06     37.39                26.0         18.0             4.0
# 288      -116.76     34.14                 4.0         42.0            10.0
# ...          ...       ...                 ...          ...             ...
# 3296     -117.87     34.04                 7.0      27700.0          4179.0
# 2969     -117.78     34.03                 8.0      32054.0          5290.0
# 2871     -117.74     33.89                 4.0      37937.0          5471.0
# 12772    -121.79     36.64                11.0      32627.0          6445.0
# 2274     -117.42     33.35                14.0      25135.0          4819.0
#
# ...

# %%
# Example 2: Sorting by two or more columns
# When sorting by multiple columns, the sorting precedence follows the order of teh list of columns passed in
df.sort_values(['population', 'total_rooms'])
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8232     -118.44     34.04                16.0         18.0             6.0
# 2990     -117.79     35.21                 4.0          2.0             2.0
# 2907     -117.76     35.22                 4.0         18.0             3.0
# 14105    -122.06     37.39                26.0         18.0             4.0
# 10911    -120.85     37.75                26.0         28.0             4.0
# ...          ...       ...                 ...          ...             ...
# 3296     -117.87     34.04                 7.0      27700.0          4179.0
# 2969     -117.78     34.03                 8.0      32054.0          5290.0
# 2871     -117.74     33.89                 4.0      37937.0          5471.0
# 12772    -121.79     36.64                11.0      32627.0          6445.0
# 2274     -117.42     33.35                14.0      25135.0          4819.0
#
# ...

# %% [markdown]
# ## Combining DataFrames
#
# Dataframes can be combined with concat, merge or join. All three methods do similar things, but they can also be more suited to certain tasks than others.
#
# For example, concat method is more suited to combining data along row or column axes with the assumption that the records that are being combined are aligned.
#
# The focus in this class will be the merge method that is used to combine two tables by specifying the primary column to merge on.

# %%
import numpy as np

# %%
df1 = pd.DataFrame(data= {'A':np.random.randint(0,100, (10,)),
                    'B':np.random.rand(10)},
             index = range(10))
df2 = pd.DataFrame(data= {'A':np.random.randint(0,100, (10,)),
                    'B':np.random.rand(10)},
             index = range(10))

# %%
df1
# Out:
#     A         B
# 0  96  0.707115
# 1   0  0.026730
# 2  32  0.008851
# 3  68  0.213539
# 4  89  0.195434
# 5  78  0.253072
# 6  76  0.255289
# 7   9  0.654932
# 8  68  0.456144
# 9  70  0.070046

# %%
df2
# Out:
#     A         B
# 0   9  0.068679
# 1  25  0.597324
# 2  23  0.283267
# 3   8  0.969155
# 4  82  0.919402
# 5  17  0.522055
# 6   9  0.180361
# 7  21  0.691420
# 8   1  0.269241
# 9  52  0.781473

# %%
pd.merge(df1, df2, left_index=True, right_index=True)
# Out:
#    A_x       B_x  A_y       B_y
# 0   96  0.707115    9  0.068679
# 1    0  0.026730   25  0.597324
# 2   32  0.008851   23  0.283267
# 3   68  0.213539    8  0.969155
# 4   89  0.195434   82  0.919402
# 5   78  0.253072   17  0.522055
# 6   76  0.255289    9  0.180361
# 7    9  0.654932   21  0.691420
# 8   68  0.456144    1  0.269241
# 9   70  0.070046   52  0.781473

# %% [markdown]
# ## Handling missing data
# Missing data are usually represented as `NaN` in Pandas. Such values can pose problem when we are trying to build machine learning models or analyse data. For this reason, they have to be handled before proceeding with processing.
#
# Pandas has built-in methods for handling missing data such as `fillna` and `dropna`. We will examine how to use these two methods.

# %%
# df.fillna
df = pd.read_html('https://github.com/pandas-dev/pandas/blob/master/doc/data/air_quality_no2.csv')[0].drop('Unnamed: 0', axis = 1)
df
# Out:
#                  datetime  station_antwerp  station_paris  station_london
# 0     2019-05-07 02:00:00              NaN            NaN            23.0
# 1     2019-05-07 03:00:00             50.5           25.0            19.0
# 2     2019-05-07 04:00:00             45.0           27.7            19.0
# 3     2019-05-07 05:00:00              NaN           50.4            16.0
# 4     2019-05-07 06:00:00              NaN           61.9             NaN
# ...                   ...              ...            ...             ...
# 1030  2019-06-20 22:00:00              NaN           21.4             NaN
# 1031  2019-06-20 23:00:00              NaN           24.9             NaN
# 1032  2019-06-21 00:00:00              NaN           26.5             NaN
# 1033  2019-06-21 01:00:00              NaN           21.8             NaN
# 1034  2019-06-21 02:00:00              NaN           20.0             NaN
#
# [1035 rows x 4 columns]

# %% [markdown]
# **`fillna`**
#
# This method has a number of ways to fillna, such as foward fill using the value of the next record, backward fill using the previous record, etc.

# %%
# Example 1: Fill nan values with a specified value
df.fillna(0)
# Out:
#                  datetime  station_antwerp  station_paris  station_london
# 0     2019-05-07 02:00:00              0.0            0.0            23.0
# 1     2019-05-07 03:00:00             50.5           25.0            19.0
# 2     2019-05-07 04:00:00             45.0           27.7            19.0
# 3     2019-05-07 05:00:00              0.0           50.4            16.0
# 4     2019-05-07 06:00:00              0.0           61.9             0.0
# ...                   ...              ...            ...             ...
# 1030  2019-06-20 22:00:00              0.0           21.4             0.0
# 1031  2019-06-20 23:00:00              0.0           24.9             0.0
# 1032  2019-06-21 00:00:00              0.0           26.5             0.0
# 1033  2019-06-21 01:00:00              0.0           21.8             0.0
# 1034  2019-06-21 02:00:00              0.0           20.0             0.0
#
# [1035 rows x 4 columns]

# %%
# Example 2: Forward fill
df.fillna(method = 'ffill')
# Out:
#                  datetime  station_antwerp  station_paris  station_london
# 0     2019-05-07 02:00:00              NaN            NaN            23.0
# 1     2019-05-07 03:00:00             50.5           25.0            19.0
# 2     2019-05-07 04:00:00             45.0           27.7            19.0
# 3     2019-05-07 05:00:00             45.0           50.4            16.0
# 4     2019-05-07 06:00:00             45.0           61.9            16.0
# ...                   ...              ...            ...             ...
# 1030  2019-06-20 22:00:00             41.0           21.4            11.0
# 1031  2019-06-20 23:00:00             41.0           24.9            11.0
# 1032  2019-06-21 00:00:00             41.0           26.5            11.0
# 1033  2019-06-21 01:00:00             41.0           21.8            11.0
# 1034  2019-06-21 02:00:00             41.0           20.0            11.0
#
# [1035 rows x 4 columns]

# %%
# Example 3: Backward fill
df.fillna(method = 'bfill')

# Alternatively, we can do:
df.bfill()
# Out:
#                  datetime  station_antwerp  station_paris  station_london
# 0     2019-05-07 02:00:00             50.5           25.0            23.0
# 1     2019-05-07 03:00:00             50.5           25.0            19.0
# 2     2019-05-07 04:00:00             45.0           27.7            19.0
# 3     2019-05-07 05:00:00             23.0           50.4            16.0
# 4     2019-05-07 06:00:00             23.0           61.9            26.0
# ...                   ...              ...            ...             ...
# 1030  2019-06-20 22:00:00              NaN           21.4             NaN
# 1031  2019-06-20 23:00:00              NaN           24.9             NaN
# 1032  2019-06-21 00:00:00              NaN           26.5             NaN
# 1033  2019-06-21 01:00:00              NaN           21.8             NaN
# 1034  2019-06-21 02:00:00              NaN           20.0             NaN
#
# [1035 rows x 4 columns]

# %%
# Example 3: Fix the errors from above by using both fill methods
df.ffill().bfill()
# Out:
#                  datetime  station_antwerp  station_paris  station_london
# 0     2019-05-07 02:00:00             50.5           25.0            23.0
# 1     2019-05-07 03:00:00             50.5           25.0            19.0
# 2     2019-05-07 04:00:00             45.0           27.7            19.0
# 3     2019-05-07 05:00:00             45.0           50.4            16.0
# 4     2019-05-07 06:00:00             45.0           61.9            16.0
# ...                   ...              ...            ...             ...
# 1030  2019-06-20 22:00:00             41.0           21.4            11.0
# 1031  2019-06-20 23:00:00             41.0           24.9            11.0
# 1032  2019-06-21 00:00:00             41.0           26.5            11.0
# 1033  2019-06-21 01:00:00             41.0           21.8            11.0
# 1034  2019-06-21 02:00:00             41.0           20.0            11.0
#
# [1035 rows x 4 columns]

# %% [markdown]
# <H1 > Welcome to Data Science Fundamentals: Pandas to Predictions</H1>
#
# <p align="center">
#   <img src="Datafain logo.jpg"/>
# </p>
#
# Hello. My name is [Ridwan Salahuddeen](https://www.linkedin.com/in/ridwan-salahuddeen/) and I shall be taking you through on this class.
#
# Follow [DataFain](https://www.linkedin.com/company/data-for-all-initiative) on LinkedIn

# %% [markdown]
# ## Table of Contents
# <font >
# <ol>
# <li> Ice Breaker: What is Data Science?, Data Science Tools, Numpy Introduction, Quiz 1
# <li> Importance of Numpy,More Hands-on Use of Numpy,Quiz 2,Assignment 1
# <li> Introduction to Pandas: Creating Dataframes and Reading From Files,Quiz 3
# <li> More on Pandas: Manipulating Dataframes,Quiz 4,Assignment 2
# <li> Introduction to Matplotlib: Plotting Simple Charts,Quiz 5
#
# <li> More on Matplotlib: Drawing Inference from plots,Quiz 6,Assignment 3
# <li> Types of Machine Learning Algorithms,Quiz 7
# <li> Understanding Learning Algorithms - Logistic Regression,Quiz 8,Assignment 4
# <li> Using Sci-Kit Learn: Logistic Regression,Sample Classification Problem1,Quiz 9
# <li> Sample Classification Problem 2,Quiz 10,Assignment 5
# </ol>
# </font>

# %% [markdown]
# ### Recap of Last Class

# %%
import numpy as np

# Random numbers creation
arr = np.random.randint(0,100, (4,5))
print(arr)
# Out:
# [[93 83 98 47 12]
#  [45 37 97 58 16]
#  [83 52 19 12 27]
#  [81 69 97 30  1]]

# %%
# Indexing and Slicing: 1) Get the second item (sub-array) in the main array
print("Example 1")
print(arr[1])

# 2) Get the last two items in the sub-arrays of the second and third sub-arrays, ie [[58, 16],[12, 27]]
print("\nExample 2")
print(arr[1:3, 3:])

# 3) Get the first and last items of all the sub-arrays, i.e = [[93, 12],[45, 16],[83,27],[81, 1]]
print("\nExample 3")
print(arr[:, [0, -1]])
# Out:
# Example 1
# [45 37 97 58 16]
#
# Example 2
# [[58 16]
#  [12 27]]
#
# Example 3
# [[93 12]
#  [45 16]
#  [83 27]
#  [81  1]]

# %%
# Universal functions: Functions that apply to every item in the array in an operation called broadcasting
# Examples are np.log, np.add, np.multiply, np.sqrt, np.power, etc
print("Example 1")
print(np.exp(arr))
print("\nExample 2")
print(np.add(arr, arr))
print("\nExample 3")
print(np.square(arr))
# Out:
# Example 1
# [[2.45124554e+40 1.11286375e+36 3.63797095e+42 2.58131289e+20
#   1.62754791e+05]
#  [3.49342711e+19 1.17191424e+16 1.33833472e+42 1.54553894e+25
#   8.88611052e+06]
#  [1.11286375e+36 3.83100800e+22 1.78482301e+08 1.62754791e+05
#   5.32048241e+11]
#  [1.50609731e+35 9.25378173e+29 1.33833472e+42 1.06864746e+13
#   2.71828183e+00]]
#
# Example 2
# [[186 166 196  94  24]
#  [ 90  74 194 116  32]
#  [166 104  38  24  54]
#  [162 138 194  60   2]]
#
# Example 3
# [[8649 6889 9604 2209  144]
#  [2025 1369 9409 3364  256]
#  [6889 2704  361  144  729]
#  [6561 4761 9409  900    1]]

# %%
# 3: Some Array attributes and methods: `dtype`, `reshape`, `shape`, `flatten`, etc
print("Example 1")
print(arr.dtype) # Attribute

print("\nExample ")
print(arr.shape) # Attribute

print("\nExample 3")
print(arr.reshape(2,10)) # method

print("Example 1")
print(arr.flatten()) # method
# Out:
# Example 1
# int32
#
# Example
# (4, 5)
#
# Example 3
# [[93 83 98 47 12 45 37 97 58 16]
#  [83 52 19 12 27 81 69 97 30  1]]
# Example 1
# [93 83 98 47 12 45 37 97 58 16 83 52 19 12 27 81 69 97 30  1]

# %% [markdown]
# # Introduction to Pandas: Creating Dataframes and Reading From Files

# %% [markdown]
# **Pandas**
#
# Pandas is one of the most useful tool you will use as a Data Scientist. It is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language. [1]('https://pandas.pydata.org/') It allows data to be displayed in tabular form and provides easy to use operations for manipulating numerical and time series data.
#
# In this program, we will cover the essentials of pandas that includes the installation, data ingestion, and some functions for transforming the data. We will also take a look at how it works with matplotlib (briefly)

# %% [markdown]
# ### Installation
#
# `pip install pandas`

# %%
# If you don't have pandas installed already, uncomment the line below.
# Optionally, you may install it from the command line using the same command as above.

#####################
#!pip install pandas

# %% [markdown]
# ### Pandas Dataframe
#
# A Pandas table is know as a Dataframe. It is built on Numpy. It leverages the speed of Numpy and offers most functionalities of Numpy. A Pandas dataframe has the view below:
#
# <img src = 'https://pandas.pydata.org/docs/_images/01_table_dataframe.svg'/>

# %% [markdown]
# ### Pandas Dataframe: Read and Write Tabular Data
#
# Pandas supports the following operations for reading and writing data from and to files.
# <img src = 'https://pandas.pydata.org/docs/_images/02_io_readwrite.svg'/>

# %% [markdown]
# ### Examples: `read_excel`, `read_csv`, `read_json` and `read_html`

# %%
# Example 1: Reading from an excel file
file_path = r"C:\Users\HP\Downloads\Complete_List_Of_Properties_In_calderdale retake-with-coordinates.xlsx"
df = pd.read_excel(file_path)
# df

# %%
# Example 2: Reading from a json file

file_path = r"C:\Users\HP\Downloads\companies.json"

df = pd.read_json(file_path)
df
# Out:
#      ae_az    us_al     us_ak          al      us_az      us_ar         au  \
# 0   305029  275-195  10017548  L21724504L  L16605259  800178087  154457388
# 1   305041  378-441  10040661  K77523502A  L19731690  811086954  630701085
# 2   301890  813-476  10022173  K34109009D  L12375317  100188479  154081535
# 3   301892  167-715  10040869  K31426040B  L13811527  811110754  125490404
# 4   308080  369-249     92349  K71820004O  L13695415  800030427   85497409
# ..     ...      ...       ...         ...        ...        ...        ...
# 85  305749  117-252    106004  K71911018L  L12629743  800151465   80878388
# 86  310555  334-514  10020786  K71917004C   13271565  811104363   54548202
# 87  309251  071-938  10064300  K02017001P  L13049625  800014653  154608081
# 88  308810  310-662    106005  K71821011C  L14310040  800111049    4540738
# 89  301817  662-484  10066297  J64103051P    2022468  800097809   94611113
#
# ...

# %%
# Example 3: From csv file
file_path = r"C:\Users\HP\Downloads\Complete_List_Of_Properties_In_calderdale retake-with-coordinates.csv"
df = pd.read_csv(file_path)
df
# Out:
#       Property reference number  \
# 0                      29004700
# 1                      29008002
# 2                      29016700
# 3                      29016701
# 4                      29020703
# ...                         ...
# 9471                   79049701
# 9472                   79051701
# 9473                   79056024
# 9474                   79057702
# 9475                   79058702
#
#                                                 Address Postcode  Latitude  \
# 0                       Aire Street, Brighouse, HD6 3RB  HD6 3RB  53.69742
# 1                   5 Waterloo Road, Brighouse, HD6 2AN  HD6 2AN  53.70514
# 2                       Archer Road, Brighouse, HD6 1XF  HD6 1XF  53.69713
# 3                       Archer Road, Brighouse, HD6 1XF  HD6 1XF  53.69713
# 4     Open View House, Armytage Road, Brighouse, HD6...  HD6 1QF  53.69661
# ...                                                 ...      ...       ...
# ...

# %%
import requests as r
a = r.get('http://covid19.ncdc.gov.ng/').content

# %%
b = r.get('https://www.worldometers.info/coronavirus/').text
type(b)
# Out:
# str

# %%
soup = bs(b, 'lxml')

# %%
import pandas as pd

pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')[0]
# Out:
#                              Bank Name           City  ST   CERT  \
# 0                 The First State Bank  Barboursville  WV  14361
# 1                   Ericson State Bank        Ericson  NE  18265
# 2     City National Bank of New Jersey         Newark  NJ  21111
# 3                        Resolute Bank         Maumee  OH  58317
# 4                Louisa Community Bank         Louisa  KY  58112
# ..                                 ...            ...  ..    ...
# 556                 Superior Bank, FSB       Hinsdale  IL  32646
# 557                Malta National Bank          Malta  OH   6629
# 558    First Alliance Bank & Trust Co.     Manchester  NH  34264
# 559  National State Bank of Metropolis     Metropolis  IL   3815
# 560                   Bank of Honolulu       Honolulu  HI  21029
#
#                    Acquiring Institution       Closing Date
# 0                         MVB Bank, Inc.      April 3, 2020
# 1             Farmers and Merchants Bank  February 14, 2020
# ...

# %%
import requests

url1 = 'http://covid19.ncdc.gov.ng/'
web_out = requests.get(url1).content
covid_df = pd.read_html(web_out)[0]
covid_df
# Out:
#    States Affected  No. of Cases (Lab Confirmed)  No. of Cases (on admission)  \
# 0            Lagos                          9741                         8140
# 1              FCT                          1676                         1126
# 2              Oyo                          1264                          748
# 3             Kano                          1191                          322
# 4           Rivers                           982                          408
# 5              Edo                           873                          573
# 6            Delta                           781                          589
# 7             Ogun                           756                          241
# 8           Kaduna                           684                          354
# 9          Katsina                           528                          239
# 10          Bauchi                           497                           61
# ...

# %% [markdown]
# ### Selecting a Subset of a Dataframe

# %% [markdown]
# #### Columns Subsetting

# %%
# Example 1: Select Number of deaths
no_of_deaths = covid_df[ 'No. of Deaths']
type(no_of_deaths)
# Out:
# pandas.core.series.Series

# %%
no_of_deaths.shape
# Out:
# (36,)

# %%
no_of_deaths.head()
# Out:
# 0    126
# 1     32
# 2     10
# 3     51
# 4     38
# Name: No. of Deaths, dtype: int64

# %%
# Example 2: Select No. of Cases (Lab Confirmed) and No. Discharged columns

covid_df[[ 'No. of Deaths', 'No. of Cases (Lab Confirmed)']].head()
# Out:
#    No. of Deaths  No. of Cases (Lab Confirmed)
# 0            126                          9741
# 1             32                          1676
# 2             10                          1264
# 3             51                          1191
# 4             38                           982

# %%
covid_df[[ 'No. of Deaths', 'No. of Cases (Lab Confirmed)']].shape
# Out:
# (36, 2)

# %% [markdown]
# #### Row Subsetting

# %%
# Creating a mask: A mask is a series or dataframe of True or False values
# For instance, let us create a mask of records with more than 30 deaths
mask = covid_df['No. of Deaths']>30
mask
# Out:
# 0      True
# 1      True
# 2     False
# 3      True
# 4      True
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# Name: No. of Deaths, dtype: bool

# %% [markdown]
# **When the mask is used to filter the dataframe, only the values that are true are returned**

# %%
# Example 1: Selecting the records of states with more than 15 deaths
mask = covid_df['No. of Deaths']>15
covid_df[mask]
# Out:
#    States Affected  No. of Cases (Lab Confirmed)  No. of Cases (on admission)  \
# 0            Lagos                          9741                         8140
# 1              FCT                          1676                         1126
# 3             Kano                          1191                          322
# 4           Rivers                           982                          408
# 5              Edo                           873                          573
# 6            Delta                           781                          589
# 7             Ogun                           756                          241
# 9          Katsina                           528                          239
# 11           Gombe                           487                          142
# 12           Borno                           477                           58
# 19            Ondo                           216                          127
#
# ...

# %%
# Example 2: Selecting states with more than 250 confirmed cases and less than 500 cases
mask = (covid_df['No. of Cases (Lab Confirmed)']>250) & (covid_df['No. of Cases (Lab Confirmed)']<500)
covid_df[mask]
# Out:
#    States Affected  No. of Cases (Lab Confirmed)  No. of Cases (on admission)  \
# 10          Bauchi                           497                           61
# 11           Gombe                           487                          142
# 12           Borno                           477                           58
# 13          Jigawa                           317                          120
# 14         Plateau                           298                          134
# 15            Abia                           297                          121
# 16          Ebonyi                           285                           37
# 17             Imo                           278                          242
#
#     No. Discharged  No. of Deaths
# 10             424             12
# 11             329             16
# 12             387             32
# 13             191              6
# 14             156              8
# 15             173              3
# ...

# %%
# Example 2: Selecting states with more than 250 confirmed cases and less than 500 cases
mask = (covid_df['No. of Cases (Lab Confirmed)']>250) & (covid_df['No. of Cases (Lab Confirmed)']<500)
covid_df[mask]
# Out:
#    States Affected  No. of Cases (Lab Confirmed)  No. of Cases (on admission)  \
# 10          Bauchi                           497                           61
# 11           Gombe                           487                          142
# 12           Borno                           477                           58
# 13          Jigawa                           317                          120
# 14         Plateau                           298                          134
# 15            Abia                           297                          121
# 16          Ebonyi                           285                           37
# 17             Imo                           278                          242
#
#     No. Discharged  No. of Deaths
# 10             424             12
# 11             329             16
# 12             387             32
# 13             191              6
# 14             156              8
# 15             173              3
# ...

# %%
# Example 2: Selecting states with more than 250 confirmed cases and less than 500 cases
mask = (covid_df['No. of Cases (Lab Confirmed)']>250) & (covid_df['No. of Cases (Lab Confirmed)']<500)
covid_df[mask]

# %%
# Example 3: Getting the records of FCT and Lagos
mask = (covid_df['States Affected'] == 'FCT')|(covid_df['States Affected'] == 'Lagos')
covid_df[mask]
# Out:
#   States Affected  No. of Cases (Lab Confirmed)  No. of Cases (on admission)  \
# 0           Lagos                          9741                         8140
# 1             FCT                          1676                         1126
#
#    No. Discharged  No. of Deaths
# 0            1475            126
# 1             518             32

# %% [markdown]
# ### Creating Plots with Pandas
#
# **Pandas plot function is an extension of Matplotlib library.**
#
# For this, we will be using the data on air quality in this [link](https://github.com/pandas-dev/pandas/tree/master/doc/data/air_quality_no2.csv)

# %%
# Read the data

df = pd.read_html('https://github.com/pandas-dev/pandas/tree/master/doc/data/air_quality_no2.csv',
                  index_col=1)[0].drop('Unnamed: 0', 1)

# %% [markdown]
# Inspect the data

# %%
df.head()
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN

# %% [markdown]
# Create a timeseries plot

# %%
df.plot(figsize = (16, 12))

# %% [markdown]
# Plotting for just London station

# %%
df['station_london'].plot(figsize = (16, 12))

# %% [markdown]
# **Scatter plot on London vs Paris air qualities**

# %%
df.plot(x = 'station_london', y = 'station_paris', kind = 'scatter', figsize = (16,12))

# %% [markdown]
# **Let us try boxplots**

# %%
df.plot(kind = 'box', figsize = (16, 12))

# %% [markdown]
# **You can also put each column in a separate plot**

# %%
ax = df.plot(kind = 'hist', figsize = (6, 16), subplots = True, bins =20)

# %% [markdown]
# ### Saving a Plot

# %%
import matplotlib.pyplot as  plt

# %%
ax = df['station_paris'].hist()
plt.savefig('paris_air_quality.png')

# %% [markdown]
# ## Practice Problems

# %% [markdown]
# 1. Load the data in this [link](https://github.com/pandas-dev/pandas/tree/master/doc/data/titanic.csv) as a dataframe
# 2. Create a subset of only females.
# 3. Create a subset of people that travelled in class 1 of the ship
# 4. Find how many survivors were on the ship
# 5. Find how many male survivors were on the ship
# 6. Create a bar plot showing the distribution of males and females.

# %%
# 1:
df = pd.read____

# %%
# 2
df_subset = ______

# %%
# 3
df_class1 = ______

# %%
# 4 
survivors = _________

# %%
# 5
male_surv = _________

# %%
# 6: Plot below
